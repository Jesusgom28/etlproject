# %%
import pandas as pd
from sqlalchemy import create_engine
pd.options.display.float_format = '{:.2f}'.format

# %%
population_file = "Resources/Population.csv"
population_data_df = pd.read_csv(population_file)
population_data_df.head()
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0                NaN                          NaN                NaN
# 1  Last Updated Date                    3/21/2019                NaN
# 2                NaN                          NaN                NaN
# 3       Country Name                 Country Code     Indicator Name
# 4              Aruba                          ABW  Population, total
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0             NaN         nan         nan         nan         nan         nan
# 1             NaN         nan         nan         nan         nan         nan
# 2             NaN         nan         nan         nan         nan         nan
# 3  Indicator Code     1960.00     1961.00     1962.00     1963.00     1964.00
# 4     SP.POP.TOTL    54211.00    55438.00    56225.00    56695.00    57032.00
#
#    Unnamed: 9     ...       Unnamed: 53  Unnamed: 54  Unnamed: 55  \
# ...

# %%
population_data_df.dropna()
# Out:
#     Data Source World Development Indicators      Unnamed: 2      Unnamed: 3  \
# 3  Country Name                 Country Code  Indicator Name  Indicator Code
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 3     1960.00     1961.00     1962.00     1963.00     1964.00     1965.00
#
#       ...       Unnamed: 53  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 3     ...           2009.00      2010.00      2011.00      2012.00
#
#    Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 3      2013.00      2014.00      2015.00      2016.00      2017.00
#
#    Unnamed: 62
# 3      2018.00
#
# [1 rows x 63 columns]

# %%
new_population_data_df.drop([0, 1, 2], inplace=True)

# %%
print(population_data_df[['Data Source', 'Unnamed: 60']])
# Out:
#                                            Data Source   Unnamed: 60
# 0                                                  NaN           nan
# 1                                    Last Updated Date           nan
# 2                                                  NaN           nan
# 3                                         Country Name       2016.00
# 4                                                Aruba     104822.00
# 5                                          Afghanistan   34656032.00
# 6                                               Angola   28813463.00
# 7                                              Albania    2876101.00
# 8                                              Andorra      77281.00
# 9                                           Arab World  406452690.00
# 10                                United Arab Emirates    9269612.00
# 11                                           Argentina   43847430.00
# 12                                             Armenia    2924816.00
# ...

# %%
new_population_data_df = population_data_df[['Data Source', 'Unnamed: 60']].copy()
new_population_data_df.head()
# Out:
#          Data Source  Unnamed: 60
# 0                NaN          nan
# 1  Last Updated Date          nan
# 2                NaN          nan
# 3       Country Name      2016.00
# 4              Aruba    104822.00

# %%
new_population_data_df.drop([0, 1, 2], inplace=True)

# %%
population_connection = "root:root@127.0.0.1/population_data_df"
engine = create_engine(f'mysql://{population_connection}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
# ...
